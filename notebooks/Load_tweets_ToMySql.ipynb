# %%
# This is Main function.
# Extracting streaming data from Twitter, pre-processing, and loading into MySQL
import credentials # Import api/access_token keys from credentials.py
import settings # Import related setting constants from settings.py 

import re
import tweepy
import mysql.connector
import pandas as pd
from textblob import TextBlob
# Streaming With Tweepy 
# http://docs.tweepy.org/en/v3.4.0/streaming_how_to.html#streaming-with-tweepy

# %%
class MyStreamListener(tweepy.StreamListener):
    '''
    Tweets are known as “status updates”. So the Status class in tweepy has properties describing the tweet.
    https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object.html
    '''
    
    def on_status(self, status):
        '''
        Extract info from tweets
        '''
        
        if status.retweeted:
            # Avoid retweeted info, and only original tweets will be received
            return True
        # Extract attributes from each tweet
        id_str = status.id_str
        created_at = status.created_at
        text = deEmojify(status.text)    # Pre-processing the text  
        sentiment = TextBlob(text).sentiment
        polarity = sentiment.polarity
        subjectivity = sentiment.subjectivity
        
        user_created_at = status.user.created_at
        user_location = deEmojify(status.user.location)
        user_description = deEmojify(status.user.description)
        user_followers_count =status.user.followers_count
        longitude = None
        latitude = None
        if status.coordinates:
            longitude = status.coordinates['coordinates'][0]
            latitude = status.coordinates['coordinates'][1]
            
        retweet_count = status.retweet_count
        favorite_count = status.favorite_count
        
        print(status.text)
        print("Long: {}, Lati: {}".format(longitude, latitude))
        
        # Store all data in MySQL
        if mydb.is_connected():
            mycursor = mydb.cursor()
            sql = "INSERT INTO {} (id_str, created_at, text, polarity, subjectivity, user_created_at, user_location, user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)".format(TABLE_NAME)
            val = (id_str, created_at, text, polarity, subjectivity, user_created_at, user_location, \
                user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count)
            mycursor.execute(sql, val)
            mydb.commit()
            mycursor.close()
    
    
    def on_error(self, status_code):
        '''
        Since Twitter API has rate limits, stop srcraping data as it exceed to the thresold.
        '''
        if status_code == 420:
            # return False to disconnect the stream
            return False

# %%
TRACK_WORDS = ['Facebook']
TABLE_NAME = "Facebook"
TABLE_ATTRIBUTES = "id_str VARCHAR(255), created_at DATETIME, text VARCHAR(255), \
            polarity INT, subjectivity INT, user_created_at VARCHAR(255), user_location VARCHAR(255), \
            user_description VARCHAR(255), user_followers_count INT, longitude DOUBLE, latitude DOUBLE, \
            retweet_count INT, favorite_count INT"

# %%
# Go to http://apps.twitter.com and create an app.
# The consumer key and secret will be generated for you
API_KEY = "vPCOQFvS2vLPohv9Toi4Mbr0W"
API_SECRET_KEY = "x00HrDFfpcX9wCL4DppEubGOU1cJD5QqdOwnjCyuAMbAM3h1nY"

# After the step above, you will be redirected to your app's page.
# Create an access token under the the "Your access token" section
ACCESS_TOKEN = "1325521853901905924-gMaJd2iZKcUQNAFpwe3iYbcUiZ6ooZ"
ACCESS_TOKEN_SECRET = "xG3Yc5GIQm7NyCl5yWWUeAVNQcqkWMQLVR9GWyff3RYN3"

# %%
def clean_tweet(self, tweet): 
    ''' 
    Use sumple regex statemnents to clean tweet text by removing links and special characters
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) \
                                |(\w+:\/\/\S+)", " ", tweet).split()) 
def deEmojify(text):
    '''
    Strip all non-ASCII characters to remove emoji characters
    '''
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %%
mydb = mysql.connector.connect(
    host="34.71.119.123",
    user="root",
    passwd="eheye",
    database="project",
    charset = 'utf8'
)
if mydb.is_connected():
    '''
    Check if this table exits. If not, then create a new one.
    '''
    print('inside')
    mycursor = mydb.cursor()
    mycursor.execute("""
        SELECT COUNT(*)
        FROM information_schema.tables
        WHERE table_name = '{0}'
        """.format(TABLE_NAME))
    if mycursor.fetchone()[0] != 1:
        mycursor.execute("CREATE TABLE {} ({})".format(TABLE_NAME, TABLE_ATTRIBUTES))
        mydb.commit()
    mycursor.close()
# Out:
# inside

# %%
auth  = tweepy.OAuthHandler(API_KEY, API_SECRET_KEY)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
myStream.filter(languages=["en"], track = TRACK_WORDS)
# Close the MySQL connection as it finished
# However, this won't be reached as the stream listener won't stop automatically
# Press STOP button to finish the process.
mydb.close()
# Out:
# RT @SidneyPowell1: And BIG TECH &amp; #Facebook #Google #Twitter are all into suppressing our freedom of speech to challenge this outrageous #E…
# Long: None, Lati: None
# RT @SB19Official: [Facebook Live NOTICE]
# Our scheduled Facebook Live tonight at 6pm will be delayed at 6:30pm. We are very sorry for letti…
# Long: None, Lati: None
# RT @PhillDKline: Systematic failures by state and local election officials to adhere to the procedures outlined in Georgia’s election code…
# Long: None, Lati: None
# RT @LennaLeprena: Tassie stuff...
# https://t.co/IO6eWwT8JH https://t.co/jE5LvfYmwP
# Long: None, Lati: None
# RT @moreland_abby: ❤️if you’re feeling the Christmas spirit &amp; wanna help me by retweeting, i would appreciate it! i just started my own pho…
# Long: None, Lati: None
# RT @Madnessauto69: This is exactly why the punishment for treason is so severe! We have the evidence to prosecute! The magic ballots are th…
# Long: None, Lati: None
# RT @espilysbb: (trans) Phi Bell, a creative working w/ Phi Toon's (Bodyslam, famous rock band in th) marathon donation posted his FB with B…
# Long: None, Lati: None
# https://t.co/9cdLZ1sfcO  Check out our Tiny House Warriors Auction for Action happening NOW.  Bidding open until De… https://t.co/lUFhGw2F8C
# Long: None, Lati: None
# RT @Brightwin4_ever: You can see the live at🍇🍊
#
# 📍https://t.co/mUd9sZlzVf
#
# #OishiPlusCxBrightWin
# #ไบร์ทวิน
# Long: None, Lati: None
# RT @shelawyer999: Former Pfizer Vice President Mike Yeadon explains that the spread of covid-19 is OVER and the public is being lied to!  h…
# Long: None, Lati: None
# RT @WORLDMUSICAWARD: #EXO’s #Kai shares more hawt teaser pics for his hugely awaited solo debut mini album 'KAI (开)' dropping November 30!…
# Long: None, Lati: None
# @seanhannity Something must be done to keep Twitter, Facebook and YouTube in check for bias and fake information. D… https://t.co/BlmT3p5x3U
# Long: None, Lati: None
# What? @Facebook SUPPRESSING a story on illegal voting? #corruptfacebook #corrupttwitter
#
# I'd be worried if I were M… https://t.co/PgX6j0XfHP
# Long: None, Lati: None
# RT @mainedcm: Thanks for making Together Tayo #BabaengBiyahero event a success! You can visit the Safe and Fair Philippines Facebook page f…
# Long: None, Lati: None
# RT @Brightwin4_ever: You can see the live at🍇🍊
#
# 📍https://t.co/mUd9sZlzVf
#
# #OishiPlusCxBrightWin
# #ไบร์ทวิน
# Long: None, Lati: None
# RT @AngryBirdsOOC: Maybe Angry Birds Seasons servers are dead... But Angry Birds Classic's are still live...
#
# Rovio news keeps getting upda…
# Long: None, Lati: None
# RT @SB19Official: Get ready as SB19, together with Tatang Robin and Hongganda will be doing a Facebook Live on Feb. 27, Thursday at 6PM! 🔥…
# Long: None, Lati: None
# RT @Varun_dvn: Arrival time note kar lijiye trailer ka! 28 Nov, 12 PM, Amazon Prime Video ke Facebook aur YouTube page par. Milte hain 🙏 #C…
# Long: None, Lati: None
# RT @Brightwin4_ever: You can see the live at🍇🍊
#
# 📍https://t.co/mUd9sZlzVf
#
# #OishiPlusCxBrightWin
# #ไบร์ทวิน
# Long: None, Lati: None
# The only view I’m getting are on my Facebook videos 😭 why 😭
# Long: None, Lati: None
# RT @KagoWaKimani: Buckle up! 🔥 Cos Its Getting Down 💯  Check  @KagoWaKimani On Facebook For Various Type Of Videos; Random,Entertainment, A…
# Long: None, Lati: None
# RT @ericthomaschu: @MgtyMicroscope Coincidentally shared this photo in a Disneyland Facebook page. 2009 Anniversary trip. https://t.co/RYhn…
# Long: None, Lati: None
# niggas be weird
# Long: None, Lati: None
# RT @Sahilwalavaid: All set to meet #CoolieNo1OnPrime 🤩
# Watch the live trailer premiere, Nov 28, on the Facebook and YouTube page of Amazon…
# Long: None, Lati: None
# Are Instagram Ads or Facebook Ads More Cost Effective? https://t.co/FpFPP1HYJQ
# Long: None, Lati: None
# RT @DeaconT17: Facebook     vs  Twitter
# Thank you all
# #Asilale available on all social streaming platforms
#
# Free downloads available
# ht…
# Long: None, Lati: None
# RT @brightwinvid: Bright and Win schedule today
#
# Oishi Plus C
#
# Time : 18:00
# Loc : G Floor Samyan Mitrtown
# Live : https://t.co/RghGafG0fI…
# Long: None, Lati: None
# @Writer_DG latest installment of daily lines from “Go Tell the Bees...” Remember, spoilers inside! In the 18th C. k… https://t.co/3R9GvcRgyG
# Long: None, Lati: None
# RT @OnlyforBrightvc: Bright Schedule 26/11/2020 🎉
#
# Oishi Plus C
# 📅 26/11/20 (Thursday)
# 🕕 6:00 pm 🇹🇭
# 📍 G Floor, Samyan Mitrtown
# 📺 FB: OiShi D…
# Long: None, Lati: None
# RT @Varun_dvn: Arrival time note kar lijiye trailer ka! 28 Nov, 12 PM, Amazon Prime Video ke Facebook aur YouTube page par. Milte hain 🙏 #C…
# Long: None, Lati: None
# Yaaaaww
# Long: None, Lati: None
# Facebook 😂😂😂
# Long: None, Lati: None
# Dope setup!
# Long: None, Lati: None
# RT @SB19Official: It's your last chance to vote for your favorite #ALABPARTY entries! 🤔💙
#
# Vote today until 11:59pm here: https://t.co/HUmnz…
# Long: None, Lati: None
# Who is dumb enough to allow the Media, Twitter, Facebook, and corrupt politicians to control your life!
#
# Answer: N… https://t.co/FabndpIKfb
# Long: None, Lati: None
# Thread for Wedding Goods !
# Long: None, Lati: None
# RT @Varun_dvn: Arrival time note kar lijiye trailer ka! 28 Nov, 12 PM, Amazon Prime Video ke Facebook aur YouTube page par. Milte hain 🙏 #C…
# Long: None, Lati: None
# RT @MelakuTedla: What the international community must know about war in #Ethiopia &amp; the real culprits &amp; Targets #AmharaGenocide @RT_com @N…
# Long: None, Lati: None
# @Tony__Heller @Twitter @YouTube @Facebook Jack Dorsey and Zuckerberg are creeps. To be fair, they are front men and… https://t.co/vNkqzKOiaN
# Long: None, Lati: None
# RT @SenHawleyPress: We the people are supposed to run this government and this nation, not the big corporations, not Big Tech. And unless C…
# Long: None, Lati: None
# RT @billboard: .@BTS_twt rules October's Top Facebook Live Videos chart  📈 https://t.co/yvtoh3vR5H
# Long: None, Lati: None
# RT @bts_bighit: #BTS 2021 SEASON'S GREETINGS Preview Cuts #2 (@ https://t.co/X7s4RRKWt5) https://t.co/dHR2HxDd9G
# Long: None, Lati: None
# RT @SkinBaronEN: G-I-V-E-A-W-A-Y 🎁
#
# What you need to do:⁠
# 1. Follow us! (@SkinBaronEN)⁠
# 2. Like!
# 3. Retweet!
#
# Visit us on Facebook and Ins…
# Long: None, Lati: None
# Parler, the “free speech” Twitter wannabe, explained https://t.co/S7E2WmcbHj via @voxdotcom
#
# I remember when "I re… https://t.co/J44Yj7dkA1
# Long: None, Lati: None
# The missing link of Biden's COVID strategy: social scientists!!
#
# https://t.co/T00Z5VwFXH
# Long: None, Lati: None
# RT @gomo_ph: GET READY. We pulled all the stops - literally. We're bringing superstars Joji, NIKI, and Chung Ha to perform at the GOMO #WeD…
# Long: None, Lati: None
# RT @YFGGpro: 🚀 YFGG Token #Airdrop is live!
#
# 💲Total Reward: 100 (YFGG) $60
#
# 🤖 Fill the form https://t.co/kfpqcb3eyt
#
# 🔉 Join Telegram Channe…
# Long: None, Lati: None
# RT @mobilebnk48home: I love you 😳,
# .
# .
# .
# baby
# And if it's quite all right
# .
# .
# .
# I need you, baby
#
# #MobileBNK48
# #BNK48
# ติดตามให้กำลังใจน้อ…
# Long: None, Lati: None
# RT @Varun_dvn: Arrival time note kar lijiye trailer ka! 28 Nov, 12 PM, Amazon Prime Video ke Facebook aur YouTube page par. Milte hain 🙏 #C…
# Long: None, Lati: None
# My New Poemवो आदमी please tab following lines  https://t.co/tAp0Amo2Ob
# Long: None, Lati: None
# RT @WORLDMUSICAWARD: Korean Superstar Group #TWICE debuts at #2 this week on the Oricon Singles Chart with their 7th Japanese Single #Bette…
# Long: None, Lati: None
# RT @Varun_dvn: Arrival time note kar lijiye trailer ka! 28 Nov, 12 PM, Amazon Prime Video ke Facebook aur YouTube page par. Milte hain 🙏 #C…
# Long: None, Lati: None
# RT @Varun_dvn: Arrival time note kar lijiye trailer ka! 28 Nov, 12 PM, Amazon Prime Video ke Facebook aur YouTube page par. Milte hain 🙏 #C…
# Long: None, Lati: None
# RT @Serenity_BWB: There will be live on Oishi Fanpage : Oishi Drink Station 👈🏻
#
# Please go follow, click See First &amp; wait
#
# #ไบร์ทวิน #Oishi…
# Long: None, Lati: None
# RT @restartleader: To find out the number of the votes for #Biden, ask Americans in an opinion poll whether they'd agree
# 1. Hassan #Rouhani…
# Long: None, Lati: None
# RT @Scobleizer: @rishab_hegde Uber was invented in front of me in a Paris snow storm. I was also the 79th user on Instagram, had the first…
# Long: None, Lati: None
# RT @SidneyPowell1: And BIG TECH &amp; #Facebook #Google #Twitter are all into suppressing our freedom of speech to challenge this outrageous #E…
# Long: None, Lati: None
# RT @gregkellyusa: My Thanksgiving “Tribute” to @JoeBiden —I don’t think he’ll like it.  https://t.co/pYCp7eq4Il
# Long: None, Lati: None
# When the Thanksgiving meal is finally served! https://t.co/q2JtIxj1a3
# Long: None, Lati: None
# Somehow Facebook knows that I both like sequins and 1960s style pumps and they’re milking the HELL out of it more t… https://t.co/yEJb1WLesd
# Long: None, Lati: None
# 😂😂😂Thank you for the new trailer @GemsOfBollywood
#
# https://t.co/rnIqKgcxdO
# Long: None, Lati: None
# RT @BTS_graphs: Please share this carrd of LGO playlists on BTS Facebook groups, Instagram stories, amino, etc.
#
# 💜 Let’s encourage other A…
# Long: None, Lati: None
# RT @dangzb: Perfect choice indeed 👍
#
# @mainedcm ☆ #MaineMendoza
# #MaineAtBFWBukasNa
# Long: None, Lati: None
# Yep, it's that time of year again - time for #ScottyTheCoward to piss off on holidays!
# https://t.co/nvnlnxwcwo
# Long: None, Lati: None
# RT @scubatsa31: SHORTAGE OF TOILET PAPER▪︎▪︎▪︎
# https://t.co/9MCSffCtjT
# Long: None, Lati: None
# @Tony__Heller @Twitter @YouTube @Facebook https://t.co/IzQem3Pj60
# The best free speech platform that is funded by the users.
# Long: None, Lati: None
# RT @SenHawleyPress: We the people are supposed to run this government and this nation, not the big corporations, not Big Tech. And unless C…
# Long: None, Lati: None
# RT @VivaArtists: Welcome to VIVA, Lyca Gairanod! ✨
#
# Catch our live press conference now on our Facebook Page! #WelcomeToVivaLyca https://t.…
# Long: None, Lati: None
# Please like, follow &amp; share our page
# Ito po page namin, feel free to visit &amp; like po 🤗
#
# https://t.co/iyyl7VGtzd
# Long: None, Lati: None
# RT @nibiru_TRUTH: grandparents just go on facebook and share 100 pictures a day that look like this https://t.co/JNeS0EXhrB
# Long: None, Lati: None
# RT @DiamondEllsy: Good morning RoyalExploras. We have a date today. Join Oriade on Facebook live with Rio Ferdinand as we talk sports. We c…
# Long: None, Lati: None
# RT @CHUNGHA_MNHent: [NOTICE]
# 💡&lt;#WeDontStop 88rising Concert&gt; LIVE 안내
#
# 🌟LIVE ON
# 2020.11.07 8PM (PHT) / 9PM (KST)
#
# 📍LIVE PAGE
# https://t.co/…
# Long: None, Lati: None
# RT @HotshotDannyD: Dec 4 @CWECanada #LiveStream Special: Fatal 4 Way #1 Contenders Match for @StardomRob's #CWE https://t.co/iL8EcjSBrJ #Ha…
# Long: None, Lati: None
# RT @UnioneItalia_CS: 4 Steering Committee PRIMIS Interreg V-A Ita-Slo2014-20
# https://t.co/BurWxqirMs @primisproject @Agenzia_Ansa @Ansa_Fvg…
# Long: None, Lati: None
# WAITING 😍
# Long: None, Lati: None
# RT @Varun_dvn: Arrival time note kar lijiye trailer ka! 28 Nov, 12 PM, Amazon Prime Video ke Facebook aur YouTube page par. Milte hain 🙏 #C…
# Long: None, Lati: None
# https://t.co/HNC7dMzUK3 Check out our Tiny House Warriors Auction for Action happening NOW.  Bidding open until Dec… https://t.co/CZWVtC8aXd
# Long: None, Lati: None
# RT @modamsshe: LMFAOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO THIS IS WHY ILL NEVER DELETE FACEBOOK BRUH! https://t.c…
# Long: None, Lati: None
# RT @Varun_dvn: Arrival time note kar lijiye trailer ka! 28 Nov, 12 PM, Amazon Prime Video ke Facebook aur YouTube page par. Milte hain 🙏 #C…
# Long: None, Lati: None
# RT @MaziNnamdiKanu: After listening to how the Fulani oligarchy loots the oil revenues but leave your land polluted and your community unde…
# Long: None, Lati: None
# RT @GLKSSS_Official: #ExclusivePictures.👌👌
# Namma @KicchaSudeep Anna's today Launched #AmrithNoni Pain Oil..!😍❤️
#
# #Kotigobba3 || #Phantom…
# Long: None, Lati: None
# Exactly how everyone else shoudl be walking around, maskless!!!
# Long: None, Lati: None
# RT @gregkellyusa: My Thanksgiving “Tribute” to @JoeBiden —I don’t think he’ll like it.  https://t.co/pYCp7eq4Il
# Long: None, Lati: None
# ⁦@criscarter80⁩ Hope you had a great birthday brother! https://t.co/njH0nQZzfW
# Long: None, Lati: None
# @TrackingCappers Have u guys looked into better oli gingras at all. I see stuff all over my Facebook says went 13-2… https://t.co/bnVhlaYADq
# Long: None, Lati: None
# RT @Varun_dvn: Arrival time note kar lijiye trailer ka! 28 Nov, 12 PM, Amazon Prime Video ke Facebook aur YouTube page par. Milte hain 🙏 #C…
# Long: None, Lati: None
# Going LIVE!  Come help us reach our goal and join us @ https://t.co/buYMaGn2Ra, https://t.co/KZ7pNTaNJp,… https://t.co/W6otuLp6tw
# Long: None, Lati: None
# RT @espilysbb: (trans) Phi Bell, a creative working w/ Phi Toon's (Bodyslam, famous rock band in th) marathon donation posted his FB with B…
# Long: None, Lati: None
# @MalumSid Your display name on Facebook ?
# Long: None, Lati: None
# RT @WORLDMUSICAWARD: Korean Superstar Group #TWICE debuts at #2 this week on the Oricon Singles Chart with their 7th Japanese Single #Bette…
# Long: None, Lati: None
# Facebook’s AI ad purge hurting small business owners ahead of holidays https://t.co/yiGblJ3SMC
# Long: None, Lati: None
# @mylightyagami Facebook
# Long: None, Lati: None
# RT @SidneyPowell1: And BIG TECH &amp; #Facebook #Google #Twitter are all into suppressing our freedom of speech to challenge this outrageous #E…
# Long: None, Lati: None
# RT @milkpowder__: Live streaming on their fb yeay! 😍 @winmetawin #winmetawin
# Long: None, Lati: None
# RT @FranksFandom: Saw this on Facebook instantly fell in love had to share #ZackSnydersJusticeLeague https://t.co/2k0GmdL0LJ
# Long: None, Lati: None
# What if we are living in slow motion at a speed of -4.5 billion. But if we weren't living here what is the speed wa… https://t.co/WDgUPGLS64
# Long: None, Lati: None
# RT @emeraldjewel1: Zuckerburg is going down. He put up $350million in cash to interfere in election plus his censoring on Facebook. Lock th…
# Long: None, Lati: None
# The fact that people my age are stupid enough to put their PHYSICAL ADDRESS on Facebook really just makes me hate life
# Long: None, Lati: None
# @pilandhare Ani Facebook Instagram ma ? 😂
# Long: None, Lati: None
# RT @nicknrm01: Christy Smith, losing centrist candidate for #CA25, sent out an email asking for money while complaining Facebook banned pol…
# Long: None, Lati: None
# @RickSteves @KeepOnTravelin  Hi Rick &amp; Team.
# Did our Reykjavik Food tour with Rick two years ago :)
#
# I think my onl… https://t.co/db77PdrYFL
# Long: None, Lati: None
# RT @Serenity_BWB: There will be live on Oishi Fanpage : Oishi Drink Station 👈🏻
#
# Please go follow, click See First &amp; wait
#
# #ไบร์ทวิน #Oishi…
# Long: None, Lati: None
# RT @binarybits: According to the NYT, Facebook knows perfectly well how to slow the spread of misinformation on its platform. It has mostly…
# Long: None, Lati: None
# @jrbixby Praise God! Sue Twitter and Facebook while you are at it, Trump and the DNC!
# Long: None, Lati: None
# RT @HawleyMO: 10 more questions for the record for Mark Zuckerberg and @jack following their testimony to the Senate Judiciary Committee. T…
# Long: None, Lati: None
# RT @Varun_dvn: Arrival time note kar lijiye trailer ka! 28 Nov, 12 PM, Amazon Prime Video ke Facebook aur YouTube page par. Milte hain 🙏 #C…
# Long: None, Lati: None
# RT @espilysbb: (trans) Phi Bell, a creative working w/ Phi Toon's (Bodyslam, famous rock band in th) marathon donation posted his FB with B…
# Long: None, Lati: None
# they're still busy voting on fb polls like "who's the most handsome" as if it will give their faves a win 😭
# Long: None, Lati: None
# RT @balikbatik: We will be at 856 G Gallery, AS Fortuna, Mandaue City from Nov 28-29, 2PM-7PM.
#
# Please wear a faceshield, facemask and fol…
# Long: None, Lati: None
# RT @WORLDMUSICAWARD: Korean Superstar Group #TWICE debuts at #2 this week on the Oricon Singles Chart with their 7th Japanese Single #Bette…
# Long: None, Lati: None
# RT @SenHawleyPress: We the people are supposed to run this government and this nation, not the big corporations, not Big Tech. And unless C…
# Long: None, Lati: None
# hopefully an ai will put a pistol in your mouth and do us all a service
# Long: None, Lati: None
# RT @ShkhAbdulRaheem: This Saturday ⏳
# Penultimate Weekend: To Love The Beloved
# With
# Shaykh Abdur Raheem D.B
#
# More details on Facebook:
# https…
# Long: None, Lati: None
# RT @Yewande92: I am largely suspicious of people under the age of 35 using Facebook. Like using the Facebook stories feature and regularly…
# Long: None, Lati: None
# RT @Varun_dvn: Arrival time note kar lijiye trailer ka! 28 Nov, 12 PM, Amazon Prime Video ke Facebook aur YouTube page par. Milte hain 🙏 #C…
# Long: None, Lati: None
# RT @AdDUCultArts: KEYNOTE 3 I We invite you to ALEGRE 2 A Webinar Series on Re/Opening Access for Culture and Arts: Arts Management in Time…
# Long: None, Lati: None
# RT @mrddmia: Translation:
#
# Dear @Facebook &amp; @Twitter:
#
# Thanks for your ongoing censorship of conservatives &amp; other election interference.…
# Long: None, Lati: None
# RT @Varun_dvn: Arrival time note kar lijiye trailer ka! 28 Nov, 12 PM, Amazon Prime Video ke Facebook aur YouTube page par. Milte hain 🙏 #C…
# Long: None, Lati: None
# RT @Varun_dvn: Arrival time note kar lijiye trailer ka! 28 Nov, 12 PM, Amazon Prime Video ke Facebook aur YouTube page par. Milte hain 🙏 #C…
# Long: None, Lati: None
# This isn't amateur hour! I'm still crushing some Call of Duty: Modern Warfare.
# https://t.co/SnnqVEGGGh
# Long: None, Lati: None
# @gabriel_zucman after seeing it advertised on Facebook? I never have. Ever. Do you know anyone who has? I am sure h… https://t.co/6eHPHkyO1z
# Long: None, Lati: None
# RT @BlackdotTwiggie: Is a date dayyyyy y'all 🗣🗣get ready to chill with Prince  and Rio on Facebook live #RioXPrinceOfGuinness https://t.co/…
# Long: None, Lati: None
# Please pledge and RT, foster or adopt this beautiful sweet dog EDDIE
# Long: None, Lati: None
# RT @Varun_dvn: Arrival time note kar lijiye trailer ka! 28 Nov, 12 PM, Amazon Prime Video ke Facebook aur YouTube page par. Milte hain 🙏 #C…
# Long: None, Lati: None
# RT @Brightwin4_ever: You can see the live at🍇🍊
#
# 📍https://t.co/mUd9sZlzVf
#
# #OishiPlusCxBrightWin
# #ไบร์ทวิน
# Long: None, Lati: None
# Oh My Gawd!  https://t.co/ZwjtUjgobD
# Long: None, Lati: None
# Woahhhh...at last❣️😁
# Long: None, Lati: None
